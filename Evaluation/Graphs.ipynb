# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_ed = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/log_30_ED_70k.csv", dtype=str)

# %%
df_ed
# Out:
#    epoch     accuracy         loss val_accuracy     val_loss
# 0      0  0.319408029  6.591235638  0.349827349  5.380403042
# 1      1   0.35416618  5.101039886  0.371471971  5.015032291
# 2      2  0.388203233  4.811240196  0.407739758  4.824203968
# 3      3  0.421020329  4.599620342  0.432430238  4.668364048
# 4      4  0.448296607   4.39948225  0.453303993  4.520153999
# 5      5  0.469642192   4.22490263  0.473519504  4.409165382
# 6      6  0.494423777  4.077963829  0.490948945  4.320370674
# 7      7   0.51142025  3.947556257  0.501172185  4.247915745
# 8      8  0.523007989  3.829205513  0.508952916  4.184439182
# 9      9  0.532890022  3.719732761  0.514914751  4.132879257
# 10    10  0.542571366  3.618022203  0.519057751  4.093883038
# 11    11  0.552026093  3.520726681  0.524240136  4.057019711
# 12    12  0.562487721  3.427078724  0.526847184  4.037748814
# 13    13  0.571786523  3.338478327  0.530412734  4.012795448
# ...

# %%
df_ed['loss'] = df_ed['loss'].astype('float').round(3)
df_ed['accuracy'] = df_ed['accuracy'].astype('float').round(3)
df_ed['val_accuracy'] = df_ed['val_accuracy'].astype('float').round(3)
df_ed['val_loss'] = df_ed['val_loss'].astype('float').round(3)

# %%
df_ed
# Out:
#    epoch  accuracy   loss  val_accuracy  val_loss
# 0      0     0.319  6.591         0.350     5.380
# 1      1     0.354  5.101         0.371     5.015
# 2      2     0.388  4.811         0.408     4.824
# 3      3     0.421  4.600         0.432     4.668
# 4      4     0.448  4.399         0.453     4.520
# 5      5     0.470  4.225         0.474     4.409
# 6      6     0.494  4.078         0.491     4.320
# 7      7     0.511  3.948         0.501     4.248
# 8      8     0.523  3.829         0.509     4.184
# 9      9     0.533  3.720         0.515     4.133
# 10    10     0.543  3.618         0.519     4.094
# 11    11     0.552  3.521         0.524     4.057
# 12    12     0.562  3.427         0.527     4.038
# 13    13     0.572  3.338         0.530     4.013
# 14    14     0.580  3.255         0.535     3.987
# 15    15     0.588  3.174         0.540     3.957
# 16    16     0.596  3.097         0.542     3.942
# 17    17     0.604  3.024         0.544     3.933
# ...

# %%
df_eda = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/logs_att_30E_70k.csv", dtype=str)

# %%
df_ed = df_ed.round(3)

# %%
type(df_ed['accuracy'][0])
# Out:
# numpy.float64

# %%
from matplotlib.pylab import plt
from numpy import arange
 
# Load the training and validation loss dictionaries
train_loss = df_ed['loss']
val_loss = df_ed['val_loss']
 
# Retrieve each dictionary's values
train_values = train_loss
val_values = val_loss
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 31)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss', linestyle='--')
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 31, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Load the training and validation loss dictionaries
train_accuracy = df_ed['accuracy']
val_accuracy = df_ed['val_accuracy']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 31)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy',  linestyle='--')
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(arange(0, 31, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
df_eda = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/logs_att_30E_70k.csv", dtype=str)

# %%
df_eda
# Out:
#    epoch     accuracy         loss val_accuracy     val_loss
# 0      0  0.550562203  4.161273956  0.566197336  3.444972515
# 1      1  0.591048241  3.262490749  0.618614197  3.179579973
# 2      2  0.633783638  2.970450401  0.645822227  2.996363401
# 3      3  0.657048404  2.748446941  0.661829293  2.871982574
# 4      4   0.67401135  2.564351559  0.671820045  2.775985479
# 5      5  0.688371062  2.405690908  0.679667413  2.705288649
# 6      6  0.701360524  2.266203403  0.686354399  2.656227589
# 7      7  0.713064313  2.142213345  0.688891351  2.620399475
# 8      8   0.72311002  2.031512737  0.689591646  2.591480255
# 9      9  0.732087195  1.930924177  0.696254611  2.566790342
# 10    10  0.740168154  1.840507269  0.697302282  2.553550243
# 11    11  0.747846246  1.757082224   0.69891721   2.54622364
# 12    12  0.755522013  1.680382252  0.695591271  2.544065714
# 13    13  0.763464391  1.609396815  0.701043963  2.534370661
# ...

# %%
df_eda['loss'] = df_eda['loss'].astype('float').round(3)
df_eda['accuracy'] = df_eda['accuracy'].astype('float').round(3)
df_eda['val_accuracy'] = df_eda['val_accuracy'].astype('float').round(3)
df_eda['val_loss'] = df_eda['val_loss'].astype('float').round(3)

# %%
df_eda
# Out:
#    epoch  accuracy   loss  val_accuracy  val_loss
# 0      0     0.551  4.161         0.566     3.445
# 1      1     0.591  3.262         0.619     3.180
# 2      2     0.634  2.970         0.646     2.996
# 3      3     0.657  2.748         0.662     2.872
# 4      4     0.674  2.564         0.672     2.776
# 5      5     0.688  2.406         0.680     2.705
# 6      6     0.701  2.266         0.686     2.656
# 7      7     0.713  2.142         0.689     2.620
# 8      8     0.723  2.032         0.690     2.591
# 9      9     0.732  1.931         0.696     2.567
# 10    10     0.740  1.841         0.697     2.554
# 11    11     0.748  1.757         0.699     2.546
# 12    12     0.756  1.680         0.696     2.544
# 13    13     0.763  1.609         0.701     2.534
# 14    14     0.772  1.543         0.695     2.546
# 15    15     0.781  1.480         0.701     2.537
# 16    16     0.789  1.422         0.698     2.540
# 17    17     0.796  1.367         0.697     2.547
# ...

# %%
# Load the training and validation loss dictionaries
train_accuracy = df_eda['accuracy']
val_accuracy = df_eda['val_accuracy']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 31)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(arange(0, 31, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Load the training and validation loss dictionaries
train_loss = df_eda['loss']
val_loss = df_eda['val_loss']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 31)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 31, 5))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # For LANG8 dataset plot diagrams

# %%
df_lang8_ed = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/EncoderDecoder_10Ep.csv", dtype=str)

# %%
df_lang8_eda = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/EncoderDecoder_10Ep.csv", dtype=str)

# %%
# For the encoder decoder model

# %%
df_lang8_ed['loss'] = df_lang8_ed['loss'].astype('float').round(3)
df_lang8_ed['accuracy'] = df_lang8_ed['accuracy'].astype('float').round(3)
df_lang8_ed['val_accuracy'] = df_lang8_ed['val_accuracy'].astype('float').round(3)
df_lang8_ed['val_loss'] = df_lang8_ed['val_loss'].astype('float').round(3)

# %%
df_lang8_ed
# Out:
#   epoch  accuracy   loss  val_accuracy  val_loss
# 0     0     0.619  2.716         0.683     2.140
# 1     1     0.706  1.959         0.720     1.846
# 2     2     0.728  1.742         0.733     1.706
# 3     3     0.737  1.621         0.738     1.631
# 4     4     0.743  1.549         0.740     1.592
# 5     5     0.747  1.497         0.742     1.561
# 6     6     0.751  1.459         0.744     1.540
# 7     7     0.753  1.427         0.744     1.527
# 8     8     0.756  1.401         0.744     1.518
# 9     9     0.758  1.379         0.746     1.510

# %%
# Load the training and validation loss dictionaries
train_accuracy = df_lang8_ed['accuracy']
val_accuracy = df_lang8_ed['val_accuracy']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 11)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(arange(0, 11, 1))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Load the training and validation loss dictionaries
train_loss = df_lang8_ed['loss']
val_loss = df_lang8_ed['val_loss']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 11)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 11, 1))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# For encoder decoder attention model lang8 dataset

# %%
df_lang8_eda['loss'] = df_lang8_eda['loss'].astype('float').round(3)
df_lang8_eda['accuracy'] = df_lang8_eda['accuracy'].astype('float').round(3)
df_lang8_eda['val_accuracy'] = df_lang8_eda['val_accuracy'].astype('float').round(3)
df_lang8_eda['val_loss'] = df_lang8_eda['val_loss'].astype('float').round(3)

# %%
df_lang8_eda
# Out:
#   epoch  accuracy   loss  val_accuracy  val_loss
# 0     0     0.619  2.716         0.683     2.140
# 1     1     0.706  1.959         0.720     1.846
# 2     2     0.728  1.742         0.733     1.706
# 3     3     0.737  1.621         0.738     1.631
# 4     4     0.743  1.549         0.740     1.592
# 5     5     0.747  1.497         0.742     1.561
# 6     6     0.751  1.459         0.744     1.540
# 7     7     0.753  1.427         0.744     1.527
# 8     8     0.756  1.401         0.744     1.518
# 9     9     0.758  1.379         0.746     1.510

# %%
# Load the training and validation loss dictionaries
train_accuracy = df_lang8_ed['accuracy']
val_accuracy = df_lang8_ed['val_accuracy']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 11)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(arange(0, 11, 1))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Load the training and validation loss dictionaries
train_loss = df_lang8_ed['loss']
val_loss = df_lang8_ed['val_loss']
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 11)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 11, 1))
 
# Display the plot
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Transformer

# %%
df_transformer = pd.read_csv("/content/drive/MyDrive/CSV_for_Data/transformer_loss.csv", dtype=float)

# %%
df_transformer
# Out:
#        Step  Training_loss  Validation_loss
# 0     500.0         0.7478         0.384734
# 1    1000.0         0.6536         0.377238
# 2    1500.0         0.6397         0.375559
# 3    2000.0         0.6118         0.359298
# 4    2500.0         0.6110         0.359002
# 5    3000.0         0.6107         0.358856
# 6    3500.0         0.6120         0.358569
# 7    4000.0         0.6103         0.358312
# 8    4500.0         0.6122         0.358017
# 9    5000.0         0.6102         0.357808
# 10   5500.0         0.6022         0.357300
# 11   6000.0         0.5947         0.355248
# 12   6500.0         0.5914         0.355057
# 13   7000.0         0.5836         0.354226
# 14   7500.0         0.5862         0.353621
# 15   8000.0         0.5842         0.353711
# 16   8500.0         0.5827         0.353211
# 17   9000.0         0.5701         0.354311
# 18   9500.0         0.5672         0.353362
# 19  10000.0         0.5675         0.353362

# %%
# Load the training and validation loss dictionaries
training_loss = df_transformer['Training_loss']
val_loss = df_transformer['Validation_loss']
 
# Generate a sequence of integers to represent the epoch numbers
steps = range(0, 10000, 500)
 
# Plot and label the training and validation loss values
plt.plot(steps, training_loss, label='Training Loss')
plt.plot(steps, val_loss, label='Validation Loss', linestyle="--")
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 10000, 1000))
 
# Display the plot
plt.legend(loc='best')
plt.show()
